# %%
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples,'g');

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]

# %%
plt.plot(years, yield_apples,'b');

# %% [markdown]
# ### Styling Lines and Markers
#
# The `plt.plot` function supports many arguments for styling lines and markers:
#
# - `color` or `c`: Set the color of the line ([supported colors](https://matplotlib.org/3.1.0/gallery/color/named_colors.html))
# - `linestyle` or `ls`: Choose between a solid or dashed line
# - `linewidth` or `lw`: Set the width of a line
# - `markersize` or `ms`: Set the size of markers
# - `markeredgecolor` or `mec`: Set the edge color for markers
# - `markeredgewidth` or `mew`: Set the edge width for markers
# - `markerfacecolor` or `mfc`: Set the fill color for markers
# - `alpha`: Opacity of the plot
#
#
# Check out the documentation for `plt.plot` to learn more: [https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) .

# %%
# For reading Documentation, Uncommnent (either oen of them) command and run it
#help(plt.plot)
#plt.plot?

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

#alpha-determines the opacity of graph
plt.plot(years, apples,color='g',marker='.',markersize=12,ls='--',lw=2)
plt.plot(years, oranges,color='b',marker='o',markersize=9,alpha=0.62,ls=':',lw=3)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# The `fmt` argument provides a shorthand for specifying the marker shape, line style, and line color. It can be provided as the third argument to `plt.plot`.
#
# `
# fmt = '[marker][line][color]'
# `

# %%
# to change figsize
plt.figure(figsize=(8,4))
#not mentioning line type will just mark the points
plt.plot(years, apples,'sr')
plt.plot(years, oranges,'o--c',markersize=6)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %% [markdown]
# You can also edit default styles directly by modifying the `matplotlib.rcParams` dictionary. Learn more: https://matplotlib.org/3.2.1/tutorials/introductory/customizing.html#matplotlib-rcparams .

# %%
matplotlib.rcParams['font.size'] = 18
matplotlib.rcParams['figure.figsize'] = (9, 5)

# %%
plt.plot(years, apples,'s:r')
plt.plot(years, oranges,'o--c',markersize=6)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
sns.set_style("whitegrid")

# %%
plt.plot(years, apples,'s:r')
plt.plot(years, oranges,'X--c',markersize=9)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
sns.set_style("darkgrid")

# %%
plt.plot(years, apples,'s:g',lw=4)
plt.plot(years, oranges,'X--b',markersize=9)
plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)');

plt.title("Crop Yields in Kanto")
plt.legend(['Apples', 'Oranges']);

# %%
#Uncomment below line for documentation
#matplotlib.rcParams

# %% [markdown]
# ## IRIS DATASET
# ___________________________
# The [Iris flower dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set) provides sample measurements of sepals and petals for three species of flowers. The Iris dataset is included with the Seaborn library and can be loaded as a Pandas data frame.

# %%
flowers_df = sns.load_dataset("iris")

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.groupby(flowers_df['species'])[['species']].count()
# Out:
#             species
# species
# setosa           50
# versicolor       50
# virginica        50

# %%
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width);

# %% [markdown]
# The above graph doesnot gove enough info to us . So lets try using `hue`

# %%
# s- size of marker
plt.figure(figsize=(13,8))
plt.title('IRIS FLOWERS')
sns.scatterplot(x=flowers_df.sepal_length,
                y=flowers_df.sepal_width,
                hue=flowers_df.species,
                s=100);

# %% [markdown]
# Seaborn has in-built support for Pandas data frames. Instead of passing each column as a series, you can provide column names and use the `data` argument to specify a data frame.

# %%
plt.title('Sepal Dimensions')
sns.scatterplot(x='sepal_length', 
                y='sepal_width', 
                hue='species',
                s=60,
                data=flowers_df);

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width,color='b');

# %% [markdown]
# bins=the interval in which histogram should be plotted.
#
# We can control the number of bins or the size of each one using the bins argument.

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width,color='b',bins=5);

# %%
import numpy as np
np.arange(2,5,0.25)
#NOTE:- it excludes 5
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#        4.75])

# %%
plt.title("Distribution of Sepal Width")
plt.hist(flowers_df.sepal_width,color='b',bins=np.arange(2,5,0.25));

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
#setosa_df

# %%
plt.hist(setosa_df.sepal_width,color='y',alpha=0.5, bins=np.arange(2, 5, 0.25));
plt.hist(versicolor_df.sepal_width,alpha=0.5, bins=np.arange(2, 5, 0.25));
plt.legend(['setosa','versicolor']);

# %% [markdown]
# ## Example :- Apples,Oranges

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.plot(years,apples,'xr--')
plt.plot(years,oranges,'sb--')

# %%
plt.bar(years,oranges,color='b',alpha=0.5)
plt.plot(years,oranges,'o--r')

# %%
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]
plt.bar(years,apples,color='orange')
plt.bar(years,oranges,bottom=apples,color='lightgreen');

# %%
plt.scatter(years,apples,color='g',s=100);

# %% [markdown]
# # Tips dataset (Seaborn inbuilt dataset)

# %%
tips_df=sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dayslist = np.unique(tips_df['day'])
dayslist
#NOTE Not all days data is given (Very important)
# Out:
# array(['Fri', 'Sat', 'Sun', 'Thur'], dtype=object)

# %%
day_mean_df=tips_df.groupby(tips_df['day'])['total_bill'].mean()
day_mean_df
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
plt.bar(dayslist,day_mean_df,color='orange');

# %%
sns.barplot(x='day',y='total_bill',data=tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### In below plot the line shows the amount of variance in the data

# %%
plt.figure(figsize=(15,11))
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df);
#You can change axis name by using plt.xlabel and plt.label . However axis names is default
plt.xlabel('Days');

# %% [markdown]
# # Heatmap
#
#
# ------------------
# A heatmap is used to visualize 2-dimensional data like a matrix or a table using colors. The best way to understand it is by looking at an example. We'll use another sample dataset from Seaborn, called `flights`, to visualize monthly passenger footfall at an airport over 12 years.

# %%
planes_df=sns.load_dataset("flights")
planes_df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
month=planes_df['month'].unique()
monthly_df=planes_df.groupby('month')['passengers'].sum()
monthly_df
# Out:
# month
# Jan    2901
# Feb    2820
# Mar    3242
# Apr    3205
# May    3262
# Jun    3740
# Jul    4216
# Aug    4213
# Sep    3629
# Oct    3199
# Nov    2794
# Dec    3142
# Name: passengers, dtype: int64

# %%
plt.rcParams['figure.figsize'] = 12,8
sns.set_style('darkgrid')
sns.barplot(x=month,y=monthly_df);

# %%
flights_df = sns.load_dataset("flights").pivot("month", "year", "passengers")
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
plt.title("No of passengers")
sns.heatmap(flights_df,cmap="YlGnBu");

# %%
sns.heatmap(flights_df,fmt="d",annot=True,cmap='Blues',linewidths=.5);

# %% [markdown]
# # Display Images :- Using matplotlib

# %% [markdown]
# ### Command :- `![](image_name.png)`
# (Just a random image from internet)
# ![](img_matplotlib.png)

# %%
from PIL import Image

# %%
img=Image.open('img_matplotlib.png')

# %%
img_array=np.array(img)

# %%
plt.imshow(img)
plt.axis('off');

# %% [markdown]
# # SUBPLOTS

# %%
fig,axes=plt.subplots(2,3,figsize=(18,15))
plt.tight_layout(pad=2)
axes[0,0].plot(years,apples,'s:b')
axes[0,0].plot(years,oranges,'o--r')
axes[0,0].legend(['apples','oranges'])
axes[0,0].set_xlabel('Years');
axes[0,0].set_ylabel('Yield');

# Pass the axes into seaborn
axes[0,1].set_title('Sepal Length vs. Sepal Width')
sns.scatterplot(x=flowers_df.sepal_length, 
                y=flowers_df.sepal_width, 
                hue=flowers_df.species, 
                s=100, 
                ax=axes[0,1]);

# Use the axes for plotting
axes[0,2].set_title('Distribution of Sepal Width')
axes[0,2].hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

axes[0,2].legend(['Setosa', 'Versicolor', 'Virginica']);

# Pass the axes into seaborn
axes[1,0].set_title('Restaurant bills')
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df, ax=axes[1,0]);

# Pass the axes into seaborn
axes[1,1].set_title('Flight traffic')
sns.heatmap(flights_df, cmap='Blues', ax=axes[1,1]);

# Plot an image using the axes
axes[1,2].set_title('Covid Graph')
axes[1,2].imshow(img)
axes[1,2].grid(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])

plt.tight_layout(pad=2);

# %% [markdown]
# # Pair plots
# -------------------------------
# ### Using `sns.pairplot`

# %%
sns.pairplot(flowers_df, hue='species');

# %%
sns.pairplot(tips_df, hue='sex');
